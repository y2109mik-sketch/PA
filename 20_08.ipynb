# %% [markdown]
# <a href="https://colab.research.google.com/github/y2109mik-sketch/PA/blob/main/20_08.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#1F Yasmin bloco-B
#pro eu dei uma pesquisada pra conseguir fazer o codigo, tinha faltado na sua ultima aula e tava meio perdida
candidatos = {1: "A", 2: "B"}
votos = {1: 0, 2: 0, "branco": 0}

eleitores = 0
votaram = 0

while True:
    idade = int(input("idade: "))
    eleitores += 1

    if idade < 16:
        print("nao vota")
    elif idade < 18:
        print("opcional")
        print("1-A 2-B 0-branco")
        voto = int(input("voto: "))
        if voto == 1:
            votos[1] += 1
        elif voto == 2:
            votos[2] += 1
        elif voto == 0:
            votos["branco"] += 1
        else:
            print("invalido")
        votaram += 1
    else:
        print("obrigatorio")
        print("1-A 2-B 0-branco")
        voto = int(input("voto: "))
        if voto == 1:
            votos[1] += 1
        elif voto == 2:
            votos[2] += 1
        elif voto == 0:
            votos["branco"] += 1
        else:
            print("invalido")
        votaram += 1

    continuar = input("mais eleitor? s/n: ")
    if continuar == "n" or continuar == "N":
        break

print("eleitores:", eleitores)
print("votaram:", votaram)
print("A:", votos[1])
print("B:", votos[2])
print("branco:", votos["branco"])

if votos[1] > votos[2] and votos[1] > votos["branco"]:
    print("ganhou A")
elif votos[2] > votos[1] and votos[2] > votos["branco"]:
    print("ganhou B")
elif votos["branco"] > votos[1] and votos["branco"] > votos[2]:
    print("branco ganhou")
else:
    print("empate")
