# %% [markdown]
# <a href="https://colab.research.google.com/github/y2109mik-sketch/PA/blob/main/02_06.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#biblioteca

import random

a = random.random()
print(a)
# Out:
# 0.697414669303341

# %%
import random

b = random.randint(0,10)
print(a)
# Out:
# 0.697414669303341

# %%
#fazer jogo de adivinhação

chute = int(input("chute um numero aleatório entre o e 10 para descobrir se esta frio ou quente!!!!"))
n = 0

while chute != 0
("")
import random

n= random.randit(0,10)

if  chute == n
elif chute != n:
  print("que pena você errou, voê tem mais 2 tentativas")

elif chute
# Out:
#   File "/tmp/ipykernel_6301/2839392110.py", line 6
#     while chute !=
#                    ^
# SyntaxError: invalid syntax
